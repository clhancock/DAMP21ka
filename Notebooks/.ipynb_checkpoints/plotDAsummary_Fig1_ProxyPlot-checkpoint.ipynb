# %% [markdown]
# **SETTiNGS**

# %%
#Select results to plot ('' will load the most recent assimilation file)
filename = '' 
filename=filename.replace('/',':')
import os
wd = '/Users/chrishancock/Library/CloudStorage/OneDrive-NorthernArizonaUniversity/Research/Manuscript/DAMP21k/Github/DAMP21ka/' #changed
os.chdir(wd+'Holocene-code') #
# Math Functions
import numpy as np
import scipy.stats
import pandas as pd
import xarray as xr
# Plotting Functions
import matplotlib.pyplot   as plt         # Packages for making figures
import matplotlib.cm       as cm
import matplotlib.gridspec as gridspec
import cartopy.crs         as ccrs        # Packages for mapping in python
import cartopy.feature     as cfeature
import cartopy.util        as cutil
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
# DA Functions
import da_utils_plotting as da_plot
import da_load_proxies
import da_load_models
import da_psms
print('packages loaded')
font = {'family': 'sans-serif', 'sans-serif': 'Lucida Grande'}
# Out:
# packages loaded

# %% [markdown]
# **LOAD DATA**

# %%
# If you don't define a reconstruction, you will load the most recent filename
filename=''
if filename == '':
    filename = [f for f in os.listdir(wd+'Data/results') if os.path.isdir(os.path.join(wd+'Data/results', f))]
    filename = filename[np.argmax([os.path.getmtime(wd+'Data/results/'+f+'/'+f+'.nc') for f in filename])]
print('loading '+filename)

# Load Data
options, DAMPvals, DAMPproxy = da_plot.loadDAMPresults(wd+'Data/results/',filename)

#Define dataframe
proxy_df = pd.DataFrame(DAMPproxy['proxy_metadata'][:,[0,1,2,3,4,5,8,10,12]], columns=['dataSetName','TSid','lat','lon','seasonality_array','season','units','archive','PSM'])
#Convert lat/lons to float (from string)
proxy_df['lat'] = [np.float(x) for x in proxy_df['lat']];
proxy_df['lon'] = [np.float(x) for x in proxy_df['lon']];

#Define mapping settings
#options['assimilate_selected_region'] = [15.0, 65.0, 190.0, 360.0]
if options['assimilate_selected_region']:
    lims,proj = [], ccrs.PlateCarree()
    for x in options['assimilate_selected_region']:
        if x < 180: lims.append(x)
        else: lims.append(x-360)
    lims = np.array(lims)[[2,3,0,1]]
else:     
    lims,proj = False, ccrs.Robinson()
# Out:
# loading DAMP21ka
# DA reconstruction loaded for variables:
# ['tas [degC]']
# ['LakeStatus [percentile]']
# ['precip [mm/day]']
# /var/folders/h9/3rpf_h5j01bcy6dw2hfhdm140000gn/T/ipykernel_4594/2104877231.py:14: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   proxy_df['lat'] = [np.float(x) for x in proxy_df['lat']];
# /var/folders/h9/3rpf_h5j01bcy6dw2hfhdm140000gn/T/ipykernel_4594/2104877231.py:15: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   proxy_df['lon'] = [np.float(x) for x in proxy_df['lon']];

# %% [markdown]
# **CALCULATE COUNT FOR EACH TIMEBIN**

# %%
#Calculate
proxy_df['agerange'],proxy_df['pctIter'],proxy_df['pctIterRound']  = np.NaN, np.NaN,np.NaN
proxy_df['pctIter'] = (np.sum(np.sum(DAMPproxy['proxies_assimilated'],axis=0)>0,axis=0)/options['number_of_i'])*100
proxy_df['agerange']= (np.sum(np.max(DAMPproxy['proxies_assimilated'],axis=1),axis=0)*options['time_resolution'])/1000
#Plot a histogram for % of iterations used by proxy records
ages = DAMPproxy['ages']
plt.hist((proxy_df['pctIter']))
plt.show()
print(np.unique(proxy_df['pctIter']))
# Out:
# [40. 50. 60. 70. 80. 90.]

# %%
#Summarize results
allproxies = np.isfinite(DAMPproxy['proxy_values']).sum(dim='proxy') 

print('minimum proxy n = ',min(allproxies.data),' at ',list(allproxies.ages[np.where(allproxies.data==min(allproxies.data))].data),' yr BP')
print('minimum Holocene data density = ',np.round(100*float(min((allproxies/max(allproxies))[ages<=11700]).data),2),'%')
print('minimum Holocene data density = ',min(allproxies[ages<=11700]).data,'records')
# Out:
# minimum proxy n =  70  at  [20249.5]  yr BP
# minimum Holocene data density =  92.59 %
# minimum Holocene data density =  200 records

# %%
#Assign sizes for shapes
s=1
u=np.unique(proxy_df['pctIter'])
proxy_df.pctIterRound = proxy_df.pctIter
proxy_df.pctIterRound[(proxy_df.pctIterRound==u[0])] = 3
proxy_df.pctIterRound[(proxy_df.pctIterRound==u[1])] = 5
proxy_df.pctIterRound[(proxy_df.pctIterRound==u[2])] = 7
proxy_df.pctIterRound[(proxy_df.pctIterRound==u[3])] = 9
proxy_df.pctIterRound[(proxy_df.pctIterRound==u[4])] = 11
proxy_df.pctIterRound[(proxy_df.pctIterRound==u[5])] = 13
proxy_df.pctIterRound[(proxy_df.pctIterRound==0)] = 1
# Out:
# /var/folders/h9/3rpf_h5j01bcy6dw2hfhdm140000gn/T/ipykernel_4594/2450629608.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   proxy_df.pctIterRound[(proxy_df.pctIterRound==u[0])] = 3
# /var/folders/h9/3rpf_h5j01bcy6dw2hfhdm140000gn/T/ipykernel_4594/2450629608.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   proxy_df.pctIterRound[(proxy_df.pctIterRound==u[1])] = 5
# /var/folders/h9/3rpf_h5j01bcy6dw2hfhdm140000gn/T/ipykernel_4594/2450629608.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   proxy_df.pctIterRound[(proxy_df.pctIterRound==u[2])] = 7
# /var/folders/h9/3rpf_h5j01bcy6dw2hfhdm140000gn/T/ipykernel_4594/2450629608.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   proxy_df.pctIterRound[(proxy_df.pctIterRound==u[3])] = 9
# /var/folders/h9/3rpf_h5j01bcy6dw2hfhdm140000gn/T/ipykernel_4594/2450629608.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   proxy_df.pctIterRound[(proxy_df.pctIterRound==u[4])] = 11
# /var/folders/h9/3rpf_h5j01bcy6dw2hfhdm140000gn/T/ipykernel_4594/2450629608.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   proxy_df.pctIterRound[(proxy_df.pctIterRound==u[5])] = 13
# /var/folders/h9/3rpf_h5j01bcy6dw2hfhdm140000gn/T/ipykernel_4594/2450629608.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   proxy_df.pctIterRound[(proxy_df.pctIterRound==0)] = 1

# %%
#Assign shapes
conditions = [
    proxy_df.TSid.astype(str).str[0:3] == 'OLS',
    proxy_df.TSid.astype(str).str[0:3] == 'pdR',
    proxy_df.TSid.astype(str).str[0:5] == 'glsdb',
    proxy_df.TSid.astype(str).str[0:3] == 'WEB', #individual
    proxy_df.TSid.astype(str).str[0:5] == 'alsdb', #Australia
    proxy_df.TSid.astype(str).str[0:3] == 'dc_', #deCort
]

choices = ['OLS', 'L&S','GLSDB','other','other','DC']

proxy_df['source'] = np.select(conditions, choices, default='none')
shapes = ['.', 'L&S','GLSDB','other','other','DC']

print(np.unique(proxy_df.source))
# Out:
# ['DC' 'GLSDB' 'L&S' 'OLS' 'other']

# %% [markdown]
# **PLOT**

# %%
import matplotlib.lines as mlines

theme = 'default'
ustr = [str(round(x)) for x in u]
ustr[-1] = ustr[-1]+'% of iterations'
#Map proxies

#Figure settings
plt.figure(figsize=(4.5,3.5),dpi=600)
plt.style.use(theme)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.rc('font', **font)
gs = gridspec.GridSpec(3,1,hspace=0)
plt.rcParams['legend.title_fontsize'] = 8

#Set Up Plot
ax1 = plt.subplot(gs[0:2],projection=ccrs.Robinson())
#ax1.set_title('Lake Proxies Used')#\n'+filename.split('_')[-1],fontsize='small',fontweight='bold')
da_plot.plotBaseMap(ax1,proj,lims)
ax2 = plt.subplot(gs[2])
ax2.bar(allproxies.ages,allproxies, width=np.diff(ages)[0],alpha=1,color='darkslateblue',label='All')

count= ages*np.NaN
for i,psm in enumerate(np.unique(proxy_df['PSM'])):
    idx = np.array((proxy_df['PSM']==psm))
    #Map Proxies
    df = proxy_df.loc[idx]
    sorti = np.argsort(np.abs(df['pctIter'])).values[::-1]
    df = df.loc[sorti]
    p=ax1.scatter(df.lon,df.lat,c=df.agerange,s=df.pctIterRound,vmin=10,vmax=21,
                  ec='k',linewidth=0.3,cmap='viridis_r',label=psm.split('_')[1],
                  transform=ccrs.PlateCarree(),zorder=1)
    # Plot each category separately
    marker_map = {'OLS': 'o', 'L&S': 'v','DC':'^','GLSDB':'s', 'other': '*'}
    for source, marker in marker_map.items():
        mask = df['source'] == source
        ax1.scatter(
            df.loc[mask, 'lon'], 
            df.loc[mask, 'lat'], 
            c=df.loc[mask, 'agerange'], 
            s=df.loc[mask, 'pctIterRound'], 
            vmin=10, vmax=21,
            ec='k', linewidth=0.3, cmap='viridis_r',
            marker=marker, label=source,
            transform=ccrs.PlateCarree(), zorder=2
        )
    #Legend1
    cbar=plt.colorbar(p,ax=ax1,use_gridspec=True,extend='both',shrink=0.7,aspect=20,ticks=range(10,21,2))
    cbar.ax.tick_params(labelsize=8) 
    cbar.set_label(label='duration of record (kyr)',size=8,position='left')
    p.remove()
    n=len(np.unique(df.pctIterRound))
    f= (lambda s: (df.pctIterRound))
    #legend
    handles, labels = p.legend_elements(prop="sizes", alpha=0.9)     
    legend1=ax1.legend(handles=handles,labels=ustr,ncol=6,loc='lower center',fontsize=7,
                       bbox_to_anchor=(0.5, -0.0),#scatterpoints=3,
            columnspacing=0.3,handletextpad=0,framealpha=1,edgecolor='k',
            )
    #Legend
    marker_handles = [mlines.Line2D([], [], color='k', marker=marker, linestyle='None', markersize=4, label=source)
                      for source, marker in marker_map.items()]
    legend2=ax1.legend(handles=marker_handles,labels=marker_map.keys(),ncol=5,loc='lower center',fontsize=7,
                       bbox_to_anchor=(0.5, -0.13),#scatterpoints=3,
            columnspacing=0.3,handletextpad=0,framealpha=1,edgecolor='k',
            )
        # Add the first legend back manually
    ax1.add_artist(legend1)

    #Time density
    countNew = np.median(np.sum(DAMPproxy['proxies_assimilated'][:,:,idx],axis=2),axis=1)
    if i == 0: ax2.bar(ages, countNew,               width=np.diff(ages)[0],color='lightsteelblue',alpha=0.8,label=psm.split('_')[1]+' ('+str(df.shape[0])+')')
    else:      ax2.bar(ages, countNew, bottom=count, width=np.diff(ages)[0],color='cornflowerblue',alpha=0.9,label=psm.split('_')[1]+' ('+str(df.shape[0])+')')
    count+=countNew
    #Adjust plot darkgrey
    ax2.grid(color='slategrey', linestyle='-.', linewidth=0.1,alpha=0.8)
    ax2.set_xlim(max(ages),min(ages)); ax2.xaxis.set_ticks((np.linspace(0,21000,8))); ax2.set_xticklabels([int(x) for x in (np.linspace(0,21,8))],size=8)
    ax2.yaxis.set_ticks((range(0,210,40)),size=8)
    ax2.set_yticklabels((range(0,210,40)),size=8)
    ax2.set_ylabel('count (#)',size=8)
    ax2.set_xlabel('age (ka)',size=8)
    ax2.legend(labels=['all records ('+str(np.max(allproxies.data))+')','records assimilated per iteration'],fontsize=7,loc='lower right')

    
ax1.text(-0.16, 0.9, '(a)', transform=ax1.transAxes,  size=8)
ax2.text(-0.12, 1.1, '(b)', transform=ax2.transAxes,  size=8)

plt.tight_layout()
plt.savefig(wd+'Data/results/'+filename+'/'+'Fig1_ProxiesUsed.png', dpi=600, bbox_inches ="tight")

# %%
#Plot pollen validation data as well
optionsValidate = options

optionsValidate['assimilate_selected_HCproxies'] = ['CalibratedPollen']
optionsValidate['proxy_datasets_to_assimilate'] = ['hydro12k']
optionsValidate['version_hydro12k'] = '0_7_0'
optionsValidate['assimilate_selected_seasons'] = ['annual']

proxy_ts,collection_all = da_load_proxies.load_proxies(options)
proxy_pollen = da_load_proxies.process_proxies(proxy_ts,collection_all,options)

proxy_pollen_df =  pd.DataFrame(proxy_pollen['metadata'][:,[0,1,2,3,5,8,10,12]], 
                                columns=['dataSetName','TSid','lat','lon','season','units','archive','PSM'])

proxy_pollen_df['lat'] = proxy_pollen['lats']
proxy_pollen_df['lon'] = proxy_pollen['lons']
# Out:
# Loading proxy dataset 1/1: hydro12k
# "seasonality" key not found for index 14272
# Number of hydro12k records selected: 350
#
# === Processing proxy data. This can take a few minutes. Please wait. ===
# Proxy 0 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 1 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 2 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 3 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 4 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 5 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 6 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 7 PSM selected: get_precip | River pollen P mm/a
# Proxy 8 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 9 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 10 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 11 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 12 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 13 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 14 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 15 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 16 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 17 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 18 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 19 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 20 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 21 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 22 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 23 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 24 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 25 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 26 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 27 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 28 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 29 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 30 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 31 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 32 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 33 PSM selected: get_precip | Mire pollen P mm/a
# Proxy 34 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 35 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 36 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 37 PSM selected: get_precip | Fen pollen P mm/a
# /Users/chrishancock/opt/anaconda3/envs/DAMP12k/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/chrishancock/Library/CloudStorage/OneDrive-NorthernArizonaUniversity/Research/Manuscript/DAMP21k/Github/DAMP21ka/Holocene-code/da_load_proxies.py:378: RuntimeWarning: Mean of empty slice
#   res_avg              = np.nanmean(proxy_res_interp[ind_selected])
# Proxy 38 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 39 PSM selected: get_precip | Bog pollen P mm/a
# Proxy 40 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 41 PSM selected: get_precip | Fluvial pollen P mm/a
# Proxy 42 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 43 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 44 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 45 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 46 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 47 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 48 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 49 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 50 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 51 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 52 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 53 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 54 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 55 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 56 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 57 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 58 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 59 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 60 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 61 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 62 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 63 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 64 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 65 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 66 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 67 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 68 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 69 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 70 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 71 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 72 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 73 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 74 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 75 PSM selected: get_precip | Bog pollen P mm/a
# Proxy 76 PSM selected: get_precip | Marsh pollen P mm/a
# Proxy 77 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 78 PSM selected: get_precip | Ocean pollen P mm/a
# Proxy 79 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 80 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 81 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 82 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 83 PSM selected: get_precip | Paleosol pollen P mm/a
# Proxy 84 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 85 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 86 PSM selected: get_precip | River pollen P mm/a
# Proxy 87 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 88 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 89 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 90 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 91 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 92 PSM selected: get_precip | Ocean pollen P mm/a
# Proxy 93 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 94 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 95 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 96 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 97 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 98 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 99 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 100 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 101 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 102 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 103 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 104 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 105 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 106 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 107 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 108 PSM selected: get_precip | Cave pollen P mm/a
# Proxy 109 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 110 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 111 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 112 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 113 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 114 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 115 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 116 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 117 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 118 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 119 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 120 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 121 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 122 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 123 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 124 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 125 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 126 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 127 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 128 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 129 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 130 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 131 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 132 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 133 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 134 PSM selected: get_precip | Marsh pollen P mm/a
# Proxy 135 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 136 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 137 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 138 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 139 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 140 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 141 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 142 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 143 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 144 PSM selected: get_precip | River pollen P mm/a
# Proxy 145 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 146 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 147 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 148 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 149 PSM selected: get_precip | Marsh pollen P mm/a
# Proxy 150 PSM selected: get_precip | Marsh pollen P mm/a
# Proxy 151 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 152 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 153 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 154 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 155 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 156 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 157 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 158 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 159 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 160 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 161 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 162 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 163 PSM selected: get_precip | Bog pollen P mm/a
# Proxy 164 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 165 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 166 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 167 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 168 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 169 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 170 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 171 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 172 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 173 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 174 PSM selected: get_precip | River pollen P mm/a
# Proxy 175 PSM selected: get_precip | Paleosol pollen P mm/a
# Proxy 176 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 177 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 178 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 179 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 180 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 181 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 182 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 183 PSM selected: get_precip | Marsh pollen P mm/a
# Proxy 184 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 185 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 186 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 187 PSM selected: get_precip | Fen pollen P mm/a
# Proxy 188 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 189 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 190 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 191 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 192 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 193 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 194 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 195 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 196 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 197 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 198 PSM selected: get_precip | Bog pollen P mm/a
# Proxy 199 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 200 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 201 PSM selected: get_precip | Creek pollen P mm/a
# Proxy 202 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 203 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 204 PSM selected: get_precip | Ocean pollen P mm/a
# Proxy 205 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 206 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 207 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 208 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 209 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 210 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 211 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 212 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 213 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 214 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 215 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 216 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 217 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 218 PSM selected: get_precip | Swamp pollen P mm/a
# Proxy 219 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 220 PSM selected: get_precip | River pollen P mm/a
# Proxy 221 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 222 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 223 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 224 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 225 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 226 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 227 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 228 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 229 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 230 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 231 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 232 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 233 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 234 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 235 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 236 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 237 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 238 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 239 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 240 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 241 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 242 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 243 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 244 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 245 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 246 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 247 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 248 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 249 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 250 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 251 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 252 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 253 PSM selected: get_precip | Marsh pollen P mm/a
# Proxy 254 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 255 PSM selected: get_precip | River pollen P mm/a
# Proxy 256 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 257 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 258 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 259 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 260 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 261 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 262 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 263 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 264 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 265 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 266 PSM selected: get_precip | River pollen P mm/a
# Proxy 267 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 268 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 269 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 270 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 271 PSM selected: get_precip | River pollen P mm/a
# Proxy 272 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 273 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 274 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 275 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 276 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 277 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 278 PSM selected: get_precip | Mire pollen P mm/a
# Proxy 279 PSM selected: get_precip | Mire pollen P mm/a
# Proxy 280 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 281 PSM selected: get_precip | Ocean pollen P mm/a
# Proxy 282 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 283 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 284 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 285 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 286 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 287 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 288 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 289 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 290 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 291 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 292 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 293 PSM selected: get_precip | Marsh pollen P mm/a
# Proxy 294 PSM selected: get_precip | Marsh pollen P mm/a
# Proxy 295 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 296 PSM selected: get_precip | Bog pollen P mm/a
# Proxy 297 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 298 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 299 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 300 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 301 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 302 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 303 PSM selected: get_precip | Lagoon pollen P mm/a
# Proxy 304 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 305 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 306 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 307 PSM selected: get_precip | Bog pollen P mm/a
# Proxy 308 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 309 PSM selected: get_precip | Bog pollen P mm/a
# Proxy 310 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 311 PSM selected: get_precip | Bog pollen P mm/a
# Proxy 312 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 313 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 314 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 315 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 316 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 317 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 318 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 319 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 320 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 321 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 322 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 323 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 324 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 325 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 326 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 327 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 328 PSM selected: get_precip | Fen pollen P mm/a
# Proxy 329 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 330 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 331 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 332 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 333 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 334 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 335 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 336 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 337 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 338 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 339 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 340 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 341 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 342 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 343 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 344 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 345 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 346 PSM selected: get_precip | Lake pollen P mm/a
# Proxy 347 PSM selected: get_precip | LakeSediment pollen P mm/a
# Proxy 348 PSM selected: get_precip | Peat pollen P mm/a
# Proxy 349 PSM selected: get_precip | Lake pollen P mm/a
#
# === PROXY DATA LOADED ===
# Proxy datasets loaded (n=1):['hydro12k']
# Proxies loaded        (n=350)
# ---
# Proxies without data in reference period (n=0)
# Proxies without uncertainty value        (n=0). Set to nan
# ---
# Data stored in dictionary "proxy_data", with keys and dimensions:
#        values_binned (350, 42)
#    resolution_binned (350, 42)
#             metadata (350, 13)
#                 lats (350,)
#                 lons (350,)
#          uncertainty (350,)
#          archivetype (350,)
#            proxytype (350,)
#                units (350,)
#               interp 350
#    seasonality_array 350
#          age_centers (42,)
# =========================

# %%
#Plot
theme = 'default'
#FOR POSTER
#Map proxies

#Figure settings
plt.figure(figsize=(8,3),dpi=400)
plt.style.use(theme)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.rc('font', **font)
gs = gridspec.GridSpec(2,1,hspace=0)
plt.rcParams['legend.title_fontsize'] = 16

#Set Up Plot
ax1 = plt.subplot(gs[:,:],projection=ccrs.Robinson())
#ax1.set_title('Lake Proxies Used')#\n'+filename.split('_')[-1],fontsize='small',fontweight='bold')
da_plot.plotBaseMap(ax1,proj,lims)
#ax2 = plt.subplot(gs[2])

count= ages*np.NaN
for i,psm in enumerate(np.unique(proxy_df['PSM'])):
    idx = np.array((proxy_df['PSM']==psm))
    #Map Proxies
    df = proxy_df.loc[idx]
    sorti = np.argsort(np.abs(df['pctIter'])).values[::-1]
    df = df.loc[sorti]
    p=ax1.scatter(df.lon,df.lat,c=df.agerange,s=df.pctIterRound*2,vmin=10,vmax=21,
                  ec='k',linewidth=0.8,cmap='viridis_r',label='Lake Status',
                  transform=ccrs.PlateCarree(),zorder=2)
    ax1.scatter(proxy_pollen_df['lon'] ,proxy_pollen_df['lat'],s=1,c='k',transform=ccrs.PlateCarree(),
                label='Pollen (precipitation)')
    cbar=plt.colorbar(p,ax=ax1,use_gridspec=True,extend='both',shrink=1,aspect=20,ticks=range(10,21,2))
    cbar.ax.tick_params(labelsize=16) 
    cbar.set_label(label='Duration of record (kyr)',size=16,position='left')
    ax1.legend(fontsize=16,loc='lower left',ncol=2,framealpha=1,columnspacing=0.3,markerscale=3) 


plt.tight_layout()
plt.show()
#plt.savefig(wd+'Data/results/'+filename+'/'+'Fig1_ProxiesUsed.png', dpi=400, bbox_inches ="tight")
